# %% [markdown]
# <a href="https://colab.research.google.com/github/darshannayak21/pds/blob/main/merging_and_sampling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # New Section

# %%
# !git clone https://github.com/darshannayak21/pds.git
# Out:
# Cloning into 'pds'...
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 4 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (4/4), 92.77 KiB | 2.26 MiB/s, done.

# %%
import pandas as pd


url1 = "/content/pds/winequality-red.csv"
url2 = "/content/pds/winequality-white.csv"
dataset = pd.read_csv(url1)
dataset2 = pd.read_csv(url2)
dataset_sample=dataset.sample(n=5, random_state=42)
display(dataset_sample)
dataset_sample2=dataset2.sample(n=5, random_state=30)
display(dataset_sample2)
con_dataset = pd.concat([dataset, dataset2])
#display(con_dataset.head())
con_datasetsample = pd.concat([dataset_sample, dataset_sample2])
display(con_datasetsample)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 803             7.7              0.56         0.08            2.50      0.114
# 124             7.8              0.50         0.17            1.60      0.082
# 350            10.7              0.67         0.22            2.70      0.107
# 682             8.5              0.46         0.31            2.25      0.078
# 1326            6.7              0.46         0.24            1.70      0.077
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 803                  14.0                  46.0   0.9971  3.24       0.66
# 124                  21.0                 102.0   0.9960  3.39       0.48
# 350                  17.0                  34.0   1.0004  3.28       0.98
# 682                  32.0                  58.0   0.9980  3.33       0.54
# 1326                 18.0                  34.0   0.9948  3.39       0.60
#
#       alcohol  quality
# 803       9.6        6
# 124       9.5        5
# 350       9.9        6
# 682       9.8        5
# 1326     10.6        6
#      fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"
# 2156  7.9;0.28;0.32;3.6;0.038;9;76;0.992;3.05;0.31;1...
# 3295  6.6;0.28;0.41;7;0.046;59;194;0.99558;3.14;0.48...
# 4760  6.6;0.17;0.26;7.4;0.052;45;128;0.99388;3.16;0....
# 2782  7.1;0.2;0.31;6.85;0.053;32;211;0.99587;3.31;0....
# 2548  6.3;0.26;0.42;7.1;0.045;62;209;0.99544;3.2;0.5...
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 803             7.7              0.56         0.08            2.50      0.114
# 124             7.8              0.50         0.17            1.60      0.082
# 350            10.7              0.67         0.22            2.70      0.107
# 682             8.5              0.46         0.31            2.25      0.078
# 1326            6.7              0.46         0.24            1.70      0.077
# 2156            NaN               NaN          NaN             NaN        NaN
# 3295            NaN               NaN          NaN             NaN        NaN
# 4760            NaN               NaN          NaN             NaN        NaN
# 2782            NaN               NaN          NaN             NaN        NaN
# 2548            NaN               NaN          NaN             NaN        NaN
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 803                  14.0                  46.0   0.9971  3.24       0.66
# 124                  21.0                 102.0   0.9960  3.39       0.48
# 350                  17.0                  34.0   1.0004  3.28       0.98
# 682                  32.0                  58.0   0.9980  3.33       0.54
# 1326                 18.0                  34.0   0.9948  3.39       0.60
# 2156                  NaN                   NaN      NaN   NaN        NaN
# 3295                  NaN                   NaN      NaN   NaN        NaN
# 4760                  NaN                   NaN      NaN   NaN        NaN
# 2782                  NaN                   NaN      NaN   NaN        NaN
# 2548                  NaN                   NaN      NaN   NaN        NaN
#
#       alcohol  quality  \
# 803       9.6      6.0
# 124       9.5      5.0
# 350       9.9      6.0
# 682       9.8      5.0
# 1326     10.6      6.0
# 2156      NaN      NaN
# 3295      NaN      NaN
# 4760      NaN      NaN
# 2782      NaN      NaN
# 2548      NaN      NaN
#
#      fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"
# 803                                                 NaN
# 124                                                 NaN
# 350                                                 NaN
# 682                                                 NaN
# 1326                                                NaN
# 2156  7.9;0.28;0.32;3.6;0.038;9;76;0.992;3.05;0.31;1...
# 3295  6.6;0.28;0.41;7;0.046;59;194;0.99558;3.14;0.48...
# 4760  6.6;0.17;0.26;7.4;0.052;45;128;0.99388;3.16;0....
# 2782  7.1;0.2;0.31;6.85;0.053;32;211;0.99587;3.31;0....
# 2548  6.3;0.26;0.42;7.1;0.045;62;209;0.99544;3.2;0.5...
